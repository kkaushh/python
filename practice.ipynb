# %%
std_marks=[20,33,45,65,77]

for i in range(len(std_marks)):
    std_marks[i]+=5
print(std_marks)
# Out:
# [25, 38, 50, 70, 82]

# %%
# %%time
list1=list(range(1,1000000))
list2=list(range(2,1000001))

list3=[]
for i in range(len(list1)):
    list3.append(list1[i]+list2[i])
# Out:
# CPU times: total: 344 ms
# Wall time: 459 ms

# %%
import numpy as np
# !!!ond-dimentional array!!!
# std_marks = np.array([23,89,90,99,91,0,34]) 
# std_marks

car=[[10,20,30],[100,200,300],[30,50,90]]
car_np = np.array(car)
car_np
car_np.shape
# Out:
# (3, 3)

# %%
import numpy as np

cars = ['kaushik'],['bmw'],['honda'],['maruthi'],['audi'],['activa']
cr=np.array(cars)
cr[1]
# Out:
# array(['bmw'], dtype='<U7')

# %%
#creating two demintional arrey numpy
import numpy as np
cars=['maruti','BMW','AUDI','HONDA','TOYATA']
manu_year=[1999,2005,2020,1947,1111]
details=np.array([cars,manu_year])
print("THE MINIMUN:",np.min(manu_year))
print("THE Maximun:",np.max(manu_year))

print(r'sum:',np.sum(manu_year))
print(r'average:',np.average(manu_year))
# Out:
# THE MINIMUN: 1111
# THE Maximun: 2020
# sum: 9082
# average: 1816.4

# %%
import numpy as np

exam_marks=[70,30,45,50,35,80,77]
internal_marks=[20,19,14,9,10,20,20]
total=np.add(exam_marks,internal_marks)
print("total marks:",total)

total=np.add(exam_marks,internal_marks)
print("PASS       :",total > 50 )
# Out:
# total marks: [ 90  49  59  59  45 100  97]
# PASS       : [ True False  True  True False  True  True]

# %%
import numpy as np

num1=np.array([1,20,40,90,20,99,45,30])
num2=np.array([30])

num3 = num1*num2
num3
# Out:
# array([  30,  600, 1200, 2700,  600, 2970, 1350,  900])

# %%
import pandas as pd
marks = [{'Chemistry': 67, 'Physics': 45, 'Mathematics': 50, 'English' : 19},
        {'Chemistry': 90, 'Physics': 92, 'Mathematics': 87, 'English' : 90}, 
        {'Chemistry': 66, 'Physics': 72, 'Mathematics': 81, 'English' : 72}, 
        {'Chemistry': 32, 'Physics': 40, 'Mathematics': 12, 'English' : 68}]
marks_df = pd.DataFrame(marks, index = ['Subodh', 'Ram', 'Abdul', 'John'])
marks_df
# Out:
#         Chemistry  Physics  Mathematics  English
# Subodh         67       45           50       19
# Ram            90       92           87       90
# Abdul          66       72           81       72
# John           32       40           12       68

# %%
f= marks_df<35
marks_df.mask(f,'fail')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f= marks_df<35
#       2 marks_df.mask(f,'fail')
#
# NameError: name 'marks_df' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

#creating 2 array
X=np.array([1,2,3,4])
Y=X**2
plt.plot(X,Y)

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
plt.plot(x,y,z)

# %%
fig=plt.figure()


#setting axes
ax = fig.add_axes([0,0,1,1])
# ax.plot(x,y,color="g",lable="line1")
ax.plot(x,y,color="g",label='line1' )
ax.plot(x,y,color="r",label='line1' )

# %%
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.plot(x,y,color="g", label='line1' )
ax.plot(x,z,color="r", label='line2')

ax.set_title('Title of the Plot',fontsize=15)    #setting title
ax.set_xlabel('Label for X axis',fontsize=15)    # setting X label
ax.set_ylabel('Label for Y axis',fontsize=15)    # setting Y _label
# Out:
# Text(0, 0.5, 'Label for Y axis')
